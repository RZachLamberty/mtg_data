# %% [markdown]
# # retag tappedout decks
#
# in order to get all decks normalized and tagged from a central source of taggings, I have built the neo4j tag database. the issue: the updated, normalized source for the "canonical" tags is metamox, which uses its own set of tags. this means I have some aliasing to do before the "source" tags and tappedout are synced. this is that work!

# %% [markdown]
# ## imports

# %%
import sys, os

sys.path.insert(0, os.path.realpath('../'))

# %%
import logging
import pickle

import networkx as nx
import numpy as np
import pandas as pd

from IPython.display import display
from ipywidgets import Button, Checkbox, Dropdown, Output, Text
from neo4j import basic_auth, GraphDatabase

from mtg.credentials import F_NEO_CONF, load_neo_config
from mtg.extract.neo4j import get_neo_tags, get_card_official_tags
from mtg.extract.tappedout import (TAPPEDOUT_SPECIAL_TAGS,
                                   TAPPEDOUT_TAGS_TO_REPLACE,
                                   TappedoutDeck,
                                   build_categories_df,
                                   get_all_categories)
from mtg.load.nx2neo import digraph_to_neo
from mtg.utils import init_logging

# %%
init_logging()

# %% [markdown]
# ## function defs

# %%
deck_id = '12-07-19-jeskai-edh'
d = TappedoutDeck(deck_id=deck_id, ignore_lands=False, with_tags=True)
# Out:
# 2019-07-25 23:57:05,568 DEBUG    [mtg.extract.tappedout.get_categories:272] loading categories for deck 12-07-19-jeskai-edh

# %%
print(d.text_description)
# Out:
# 1x Adarkar Wastes
# 1x Aetherflux Reservoir #lifegain #spell_slinger #amplify #wincon
# 1x Ancient Tomb
# 1x Anointed Procession #copy #token_source #amplify
# 1x Arcane Denial #card_advantage #counter
# 1x Arclight Phoenix
# 1x Arid Mesa
# 1x Ashnod's Altar
# 1x Austere Command
# 1x Azorius Chancery
# 1x Azorius Signet
# 1x Battle Hymn #ramp #amplify
# 1x Battlefield Forge
# 1x Bident of Thassa
# 1x Blasphemous Act
# 1x Bloodstained Mire
# 1x Bonus Round
# 1x Boros Charm #burn #indestructible #stopgap
# 1x Boros Garrison
# 1x Boros Signet
# 1x Brainstorm #cantrip #card_advantage
# 1x Cascade Bluffs
# 1x Cathars' Crusade
# 1x Chaos Warp #removal #removal_all
# 1x Chromatic Lantern
# 1x Chrome Mox
# 1x City of Brass
# 1x Clifftop Retreat
# 1x Comet Storm #burn #other_removal #removal #storm
# 1x Command Tower
# 1x Commander's Sphere
# 1x Counterflux #counter
# 1x Counterspell #cantrip #counter #hard_counter #mass_removal #removal #stopgap
# 1x Cyclonic Rift #board_wipes #mass_removal #permanents_-_mass_bounce #removal #removal_all
# 1x Dack Fayden
# 1x Desolate Lighthouse
# 1x Dig Through Time #card_advantage #delve #standalone
# 1x Disallow
# 1x Distant Melody
# 1x Divergent Transformations
# 1x Divine Visitation
# 1x Docent of Perfection #+1/+1_counter_source #spell_slinger #token_source
# 1x Dovin's Veto #counter #noncreature_permanent_-_counter #stopgap
# 1x Dramatic Reversal #untap #stopgap
# 1x Earthquake
# 1x Echo of Eons
# 1x Electrodominance
# 1x Elspeth, Sun's Champion
# 1x Enlightened Tutor #search_for_artifact #search_for_enchantment #search_to_top_of_library #tutors #standalone
# 1x Evolving Wilds
# 1x Exotic Orchard
# 1x Expansion / Explosion #burn #redirect #wincon
# 1x Expedite #cantrip
# 1x Fabricate
# 1x Fact or Fiction #card_advantage #dig #draw
# 1x Faithless Looting #card_advantage #flashback #loot #other_loot #recursion #standalone
# 1x Fellwar Stone
# 1x Fiery Islet
# 1x Finale of Promise
# 1x Finale of Revelation
# 1x Flooded Strand
# 1x Flusterstorm #counter #storm #stopgap
# 1x Force of Negation
# 1x Frantic Search #cantrip #card_advantage #loot #other_loot
# 1x Future Sight
# 1x Gamble
# 1x Generous Gift #removal #removal_all
# 1x Gitaxian Probe #cantrip #card_advantage #disruption #manaless
# 1x Glacial Fortress
# 1x Goblin Bombardment
# 1x Goblin Electromancer #cost_reduction #cost_reduction_-_spells #ramp #spell_slinger #amplify
# 1x Guttersnipe #spell_slinger #amplify #tokens_matter #wincon
# 1x Hall of Heliod's Generosity
# 1x Hallowed Fountain
# 1x Impact Tremors #burn #amplify #creatures_matter #tokens_matter #wincon
# 1x Impulse
# 1x Inspiring Vantage
# 1x Intangible Virtue
# 1x Irrigated Farmland
# 1x Isochron Scepter
# 1x Izzet Boilerworks
# 1x Izzet Charm #counter #modal #noncreature_-_counter
# 1x Izzet Guildgate
# 1x Izzet Signet
# 1x Jace's Sanctum
# 1x Jeskai Ascendancy #card_advantage #loot #spell_slinger #untap #amplify
# 1x Jeskai Charm #burn #creature_removal #lifelink #removal
# 1x Kindred Discovery
# 1x Kykar, Wind's Fury
# 1x Lightning Greaves
# 1x Lotus Petal
# 1x Mana Confluence
# 1x Mana Drain #counter #ramp
# 1x Mana Echoes
# 1x Mana Geyser
# 1x Mana Vault
# 1x Marsh Flats
# 1x Mentor of the Meek #card_advantage #amplify #tokens_matter
# 1x Merchant Scroll
# 1x Metallurgic Summonings
# 1x Mind Stone
# 1x Mission Briefing
# 1x Misty Rainforest
# 1x Mizzix's Mastery
# 1x Monastery Mentor #bomb #spell_slinger #token_source #standalone
# 1x Mountain
# 1x Murmuring Mystic #+1/+1_counter_source #evasive #spell_slinger #token_source
# 1x Mystic Confluence
# 1x Mystic Monastery
# 1x Mystic Remora
# 1x Mystic Retrieval
# 1x Mystical Tutor #search_for_instant #search_for_sorcery #search_to_top_of_library #tutors #standalone
# 1x Narset Transcendent
# 1x Narset's Reversal #counter #redirect
# 1x Narset, Parter of Veils
# 1x Negate #counter #stopgap
# 1x Niv-Mizzet, Parun #3_devotion #blue_devotion #burn #card_advantage #devotion #draw #evasive #pinger #red_devotion #standalone
# 1x Opt #cantrip #card_advantage #dig #draw #scry
# 1x Pact of Negation
# 1x Past in Flames #flashback #recursion #stopgap
# 1x Path to Exile #creature_-_exile #creature_removal #removal
# 1x Phyrexian Altar
# 1x Polluted Delta
# 1x Ponder #cantrip #card_advantage #dig
# 1x Prairie Stream
# 1x Preordain #cantrip #card_advantage #scry
# 1x Primal Amulet
# 1x Prismatic Vista
# 1x Pull from Tomorrow
# 1x Purphoros, God of the Forge #bomb #burn #devotion #devotion_matters #direct_damage #indestructible #mana_sink #spell_slinger #standalone #tokens_matter #wincon
# 1x Ral, Izzet Viceroy
# 1x Ral, Storm Conduit
# 1x Reflecting Pool
# 1x Reliquary Tower
# 1x Render Silent
# 1x Return to Dust
# 1x Reverberate #copy #copy_instant #copy_sorcery #redirect #amplify
# 1x Rhystic Study
# 1x Rugged Prairie
# 1x Sacred Foundry
# 1x Saheeli Rai
# 1x Saheeli, Sublime Artificer #+1/+1_counter_source #spell_slinger #token_source #engine #standalone
# 1x Scalding Tarn
# 1x Sea of Clouds
# 1x Search for Azcanta
# 1x Sensei's Divining Top
# 1x Serum Visions
# 1x Shared Animosity
# 1x Shivan Reef
# 1x Skullclamp #card_advantage #equipment
# 1x Sleight of Hand
# 1x Smothering Tithe #ramp #taxes #fixing #standalone
# 1x Snow-Covered Island
# 1x Snow-Covered Mountain
# 1x Snow-Covered Plains
# 1x Sol Ring
# 1x Soulfire Grand Master #bomb #recurring_card_advantage #recurring_lifegain #recursion #amplify
# 1x Sphinx's Revelation #draw #lifegain
# 1x Spirebluff Canal
# 1x Spirit Bonds
# 1x Steam Vents
# 1x Sulfur Falls
# 1x Sunbaked Canyon
# 1x Sunforger
# 1x Supreme Verdict
# 1x Swan Song #counter #noncreature_permanent_-_counter #removal
# 1x Swiftfoot Boots
# 1x Swiftwater Cliffs
# 1x Swords to Plowshares #bomb #creature_-_exile #creature_removal #lifegain #removal
# 1x Taigam, Ojutai Master #spell_slinger #standalone
# 1x Talisman of Conviction #boros #mana_rocks #ramp #fixing #tier2
# 1x Talisman of Creativity #izzet #mana_rocks #ramp #fixing #tier2
# 1x Talisman of Progress #1_colorless #azorius #mana_rocks #ramp #talismans #fixing #tier2
# 1x Talrand, Sky Summoner #evasive #spell_slinger #token_source #engine
# 1x Teferi's Protection
# 1x Teferi, Hero of Dominaria
# 1x Teferi, Time Raveler
# 1x Temple of Enlightenment
# 1x Temple of Epiphany #izzet #lands #scry #scry_lands #fixing
# 1x Temple of Triumph
# 1x Terramorphic Expanse
# 1x The Locust God #card_advantage #evasive #token_source #standalone
# 1x Thought Vessel
# 1x Thousand-Year Storm
# 1x Time Spiral
# 1x Time Wipe
# 1x Tranquil Cove
# 1x Treasure Cruise
# 1x Trinket Mage #cost_reduction #other_cost_reduction #search_by_cmc #search_for_artifact #tutors
# 1x Twilight Drover #token_source #amplify #tokens_matter
# 1x Vandalblast
# 1x Wayfarer's Bauble
# 1x Wear #artifact_removal #enchantment_removal #removal
# 1x Wheel of Fortune
# 1x Wind-Scarred Crag
# 1x Windfall
# 1x Winds of Abandon
# 1x Windswept Heath
# 1x Wooded Foothills
# 1x Young Pyromancer #+1/+1_counter_source #spell_slinger #token_source #standalone

# %% [markdown]
# goal: every card gets (and only gets) tags that satisfy one of the following
#
# + it is any of the "official" tags connected to it in neo (at any distance)
#     + e.g. `(c:Card)-[*]->(t:Tag)`
# + it is a tappedout tag that has no alias to real tags
#     + e.g. `#already_have_this` stays, but `#lifegain` doesn't
#         + `(to:TappedoutTag {name: "#lifegain"})-[:IS_ALIAS_OF]->(t:Tag {name: "Lifegain"})`
# + it is one of the special tags that is deck-specific
#     + e.g. `#amplify` stays for cards in decks where `(c:Card)-[:HAS_TAG]->(t:Tag {name: "{deck_id} - Amplify"})`
#
# if a given tag doesn't satisfy one of those criteria, it will be removed. *note: this basically means "remove all tags that have 'real' aliases"*

# %%
neo_conf = load_neo_config(F_NEO_CONF)

# %%
# hack to make sure that the get_card_official_tags function gets
# updated; remove when done
import mtg.extract.neo4j as N
import importlib
importlib.reload(N)

get_card_official_tags = N.get_card_official_tags

# %% [markdown]
# ### official tags

# %%
tags_official = pd.DataFrame(get_card_official_tags(neo_conf,
                                                    card_names=d.df.name.unique().tolist()),
                             columns=['name', 'tag'])
# Out:
# 2019-07-25 23:57:53,920 INFO     [bulk_rename_tappedout_tags.get_card_official_tags:76] loading all official tags for 200 cards

# %%
tags_official.head()
# Out:
#                    name                            tag
# 0        Adarkar Wastes                     Pain Lands
# 1        Adarkar Wastes                          Lands
# 2        Adarkar Wastes                   Azorius Mana
# 3  Aetherflux Reservoir  12-07-19-jeskai-edh - Amplify
# 4  Aetherflux Reservoir   12-07-19-jeskai-edh - Wincon

# %% [markdown]
# drop the deck-specific tags as they could have only gotten to this side from tappedout to begin with

# %%
is_special = (tags_official
              .tag
              .str.contains('|'.join(TAPPEDOUT_SPECIAL_TAGS), case=False))

tags_official = tags_official[~is_special]

# %% [markdown]
# ### deck specific tags
#
# this set of tags exists as a constant across tappedout decks and is available as

# %%
TAPPEDOUT_SPECIAL_TAGS
# Out:
# ['amplify', 'engine', 'standalone', 'stopgap', 'wincon']

# %% [markdown]
# ### aliased tags
#
# these are to be *removed*, not kept

# %%
_, _, aliases = get_neo_tags(neo_conf)
tags_aliases = pd.DataFrame(aliases, columns=['tappedout_tag', 'tag'])
# Out:
# 2019-07-25 23:57:54,286 INFO     [bulk_rename_tappedout_tags.get_neo_tags:45] loading all known tags from bolt://localhost:7687
# 2019-07-25 23:57:54,297 INFO     [bulk_rename_tappedout_tags.get_neo_tags:51] loading all known tapped out alias tags from bolt://localhost:7687
# 2019-07-25 23:57:54,305 INFO     [bulk_rename_tappedout_tags.get_neo_tags:57] loading all known tapped out alias connections from bolt://localhost:7687

# %%
tags_aliases.head()
# Out:
#   tappedout_tag              tag
# 0       evasion          Evasive
# 1        extort           Extort
# 2        faerie  Tribal - Faerie
# 3        fearie  Tribal - Faerie
# 4  first strike    Combat Tricks

# %% [markdown]
# ### actually doing the mapping
#
# we'll create one function to do this and apply it across the records

# %%
def clean_tappedout_tag(t):
    t = t.replace('#', '').replace('_', ' ')
    # remap some of them
    t = TAPPEDOUT_TAGS_TO_REPLACE.get(t, t)
    return t

def fix_tag_list(rec):
    name = rec['name']
    tag_list = rec.tag_list
    try:
        tags = {clean_tappedout_tag(t) for t in tag_list}
    except TypeError:
        tags = set()
    
    validated_tags = set()

    # add the "white list" tags from the database
    validated_tags.update(tags_official
                          [tags_official.name == name]
                          .tag
                          .unique())

    # add any "deck specific" tags
    special_tags = tags.intersection(TAPPEDOUT_SPECIAL_TAGS)
    validated_tags.update(special_tags)
    tags.difference_update(special_tags)

    # drop anything aliased (alias on the other side should
    # have been added above)
    tags.difference_update(tags_aliases.tappedout_tag.values)

    # anything that remains is good to add back in
    validated_tags.update(tags)

    return ['#{}'.format(_.replace(' ', '_'))
            for _ in sorted(validated_tags)]

# %% [markdown]
# replace the existing tag column in the df with the fixed one

# %%
d.df.loc[:, 'tag_list_old'] = d.df.tag_list
d.df.tag_list = d.df.apply(fix_tag_list, axis=1)

# %%
print(d.text_description)
# Out:
# 1x Adarkar Wastes #Azorius_Mana #Lands #Pain_Lands
# 1x Aetherflux Reservoir #Lifegain #Spell_Slinger #amplify #spell_slinger #wincon
# 1x Ancient Tomb #Lands #Multiple_Colorless_Lands #Ramp
# 1x Anointed Procession #Copy #Token_Source #amplify #copy #token_source
# 1x Arcane Denial #Card_Advantage #Counter #card_advantage
# 1x Arclight Phoenix #Reanimate #Reanimate_-_Creature #Recursion
# 1x Arid Mesa #Fetches #Lands #Pain_Lands
# 1x Ashnod's Altar #2_Colorless #Mana_Rocks #Sacrifice_Outlet
# 1x Austere Command #Artifact_Removal #Artifacts_-_Mass_Destroy #Board_Wipes #Cost_Reduction #Creature_Removal #Creatures_-_Mass_Destroy #Enchantment_Removal #Enchantments_-_Mass_Destroy #Mass_Removal #Other_Cost_Reduction #Removal
# 1x Azorius Chancery #Azorius_Mana #Bounce_Lands #Lands
# 1x Azorius Signet #Azorius_Mana #Mana_Rocks #Ramp #Signets
# 1x Battle Hymn #Ramp #amplify
# 1x Battlefield Forge #Lands #Pain_Lands
# 1x Bident of Thassa #Bomb #Card_Advantage #Combat_Tricks #Draw #Recurring_Card_Advantage
# 1x Blasphemous Act #Board_Wipes #Creatures_-_Mass_Damage
# 1x Bloodstained Mire #Fetch_Basic #Fetches #Lands #Rakdos_Mana #Tutors
# 1x Bonus Round #Copy #Copy_Instant #Copy_Sorcery #Copy_Spell
# 1x Boros Charm #Burn #Indestructible #indestructible #stopgap
# 1x Boros Garrison #Bounce_Lands #Lands #Ramp
# 1x Boros Signet #Mana_Rocks #Signets
# 1x Brainstorm #Cantrip #Card_Advantage #card_advantage
# 1x Cascade Bluffs #Filter_Lands #Izzet_Mana #Lands
# 1x Cathars' Crusade #+1/+1_Counter_Source #Anthem #Enter_the_Battlefield
# 1x Chaos Warp #Removal #removal_all
# 1x Chromatic Lantern #Any_Color #Mana_Rocks #Ramp
# 1x Chrome Mox #Mana_Rocks #Other_Mana_Rocks #Ramp
# 1x City of Brass #Any_Color_Lands #Lands
# 1x Clifftop Retreat #Check_Lands #Lands
# 1x Comet Storm #Burn #Other_Removal #Removal #Storm #other_removal
# 1x Command Tower #Any_Color_Lands #Lands
# 1x Commander's Sphere #Card_Advantage #Draw #Mana_Rocks #Other_Mana_Rocks #Ramp
# 1x Counterflux
# 1x Counterspell #Cantrip #Counter #Hard_Counter #Mass_Removal #Removal #hard_counter #mass_removal #stopgap
# 1x Cyclonic Rift #Board_Wipes #Mass_Removal #Permanents_-_Mass_Bounce #Removal #board_wipes #mass_removal #permanents_-_mass_bounce #removal_all
# 1x Dack Fayden #Card_Advantage #Draw #Loot #Theft #Theft_-_Indefinite
# 1x Desolate Lighthouse #Card_Advantage #Draw #Draw_Lands #Lands #Loot
# 1x Dig Through Time #Card_Advantage #Delve #card_advantage #delve #standalone
# 1x Disallow #Activation_Hate #Counter #Hate
# 1x Distant Melody #Card_Advantage #Draw #Tribal_-_Faerie
# 1x Divergent Transformations #Creature_-_Destroy #Creature_Removal #Multiplayer #Polymorph #Removal #Undaunted
# 1x Divine Visitation #Token_Source
# 1x Docent of Perfection #+1/+1_Counter_Source #+1/+1_counter_source #Spell_Slinger #Token_Source #spell_slinger #token_source
# 1x Dovin's Veto #Counter #Noncreature_Permanent_-_Counter #noncreature_permanent_-_counter #stopgap
# 1x Dramatic Reversal #Untap #stopgap
# 1x Earthquake #Board_Wipes #Creatures_-_Mass_Damage
# 1x Echo of Eons #Card_Advantage #Draw #Flashback
# 1x Electrodominance #Creature_Removal #Planeswalker_Removal #Removal
# 1x Elspeth, Sun's Champion #Board_Wipes #Bomb #Creatures_-_Mass_Destroy #Mass_Removal #Recurring_Card_Advantage #Removal #Token_Source
# 1x Enlightened Tutor #Search_For_Artifact #Search_For_Enchantment #Search_To_Top_Of_Library #Tutors #search_for_artifact #search_for_enchantment #search_to_top_of_library #standalone #tutors
# 1x Evolving Wilds #Basic_Fetches #Fetch_Basic #Fetch_Land #Lands #Tutors
# 1x Exotic Orchard #Any_Color_Lands #Lands
# 1x Expansion / Explosion #Burn #Redirect #wincon
# 1x Expedite #Cantrip
# 1x Fabricate #Search_For_Artifact #Tutors
# 1x Fact or Fiction #Card_Advantage #Dig #Draw #card_advantage #dig #draw
# 1x Faithless Looting #Card_Advantage #Flashback #Loot #Other_Loot #Recursion #card_advantage #flashback #other_loot #standalone
# 1x Fellwar Stone #Mana_Rocks #Other_Mana_Rocks
# 1x Fiery Islet #Card_Advantage #Draw #Izzet_Mana
# 1x Finale of Promise #Copy #Copy_Instant #Copy_Spell #Flashback
# 1x Finale of Revelation #Card_Advantage #Draw
# 1x Flooded Strand #Azorius_Mana #Fetch_Land #Fetches #Lands #Tutors
# 1x Flusterstorm #Counter #Storm #stopgap
# 1x Force of Negation #Counter
# 1x Frantic Search #Cantrip #Card_Advantage #Loot #Other_Loot #card_advantage #other_loot
# 1x Future Sight #3_Devotion #Blue_Devotion #Card_Advantage #Devotion
# 1x Gamble #Tutor_Any_Card #Tutors
# 1x Generous Gift #Removal #removal_all
# 1x Gitaxian Probe #Cantrip #Card_Advantage #Disruption #Manaless #card_advantage #manaless
# 1x Glacial Fortress #Azorius_Mana #Check_Lands #Lands
# 1x Goblin Bombardment #Direct_Damage #Sacrifice_Outlet
# 1x Goblin Electromancer #Cost_Reduction #Cost_Reduction_-_Spells #Ramp #Spell_Slinger #amplify #cost_reduction #cost_reduction_-_spells #spell_slinger
# 1x Guttersnipe #Spell_Slinger #amplify #spell_slinger #tokens_matter #wincon
# 1x Hall of Heliod's Generosity #Reanimate #Reanimate_-_Enchantment #Recursion
# 1x Hallowed Fountain #Azorius_Mana #Lands #Shock_Lands
# 1x Impact Tremors #Burn #amplify #creatures_matter #tokens_matter #wincon
# 1x Impulse #Card_Advantage #Draw
# 1x Inspiring Vantage #Fast_Lands #Lands
# 1x Intangible Virtue #+1/+1_Counter_Source #Combat_Tricks
# 1x Irrigated Farmland #Azorius_Mana #Cycling #Cycling_Lands #Lands
# 1x Isochron Scepter #Copy #Copy_Instant #Cost_Reduction #Other_Cost_Reduction #Recursion
# 1x Izzet Boilerworks #Bounce_Lands #Lands
# 1x Izzet Charm #Creature_Removal #Loot #Other_Loot #Removal #modal #noncreature_-_counter
# 1x Izzet Guildgate #Gates #Izzet_Mana #Lands
# 1x Izzet Signet #Mana_Rocks #Signets
# 1x Jace's Sanctum #Cost_Reduction #Cost_Reduction_-_Spells #Scry
# 1x Jeskai Ascendancy #Card_Advantage #Loot #Spell_Slinger #Untap #amplify #card_advantage #spell_slinger
# 1x Jeskai Charm #Burn #Creature_Removal #Lifelink #Removal #creature_removal
# 1x Kindred Discovery #Card_Advantage #Draw #Tribal_-_Faerie
# 1x Kykar, Wind's Fury #Token_Source
# 1x Lightning Greaves #Combat_Tricks #Equipment #Evasive
# 1x Lotus Petal #Mana_Rocks #Ramp #Trinkets
# 1x Mana Confluence #Any_Color_Lands #Lands
# 1x Mana Drain
# 1x Mana Echoes #Ramp
# 1x Mana Geyser #Ramp
# 1x Mana Vault #3_Colorless #Mana_Rocks #Ramp
# 1x Marsh Flats #Fetch_Land #Fetches #Lands #Tutors
# 1x Mentor of the Meek #Card_Advantage #amplify #card_advantage #tokens_matter
# 1x Merchant Scroll #Search_For_Instant #Tutors
# 1x Metallurgic Summonings #Board_Wipes #Recursion #Sorcery_-_Mass_Bounce #Token_Source
# 1x Mind Stone #1_Colorless #Card_Advantage #Draw #Mana_Rocks
# 1x Mission Briefing #Cost_Reduction #Cost_Reduction_-_Spells #Dredge #Lands
# 1x Misty Rainforest #Fetch_Land #Fetches #Lands #Tutors
# 1x Mizzix's Mastery #Flashback #Recursion
# 1x Monastery Mentor #Bomb #Spell_Slinger #Token_Source #bomb #spell_slinger #standalone #token_source
# 1x Mountain
# 1x Murmuring Mystic #+1/+1_Counter_Source #+1/+1_counter_source #Evasive #Spell_Slinger #Token_Source #evasive #spell_slinger #token_source
# 1x Mystic Confluence #Card_Advantage #Counter #Creature_-_Bounce #Draw #Removal
# 1x Mystic Monastery #Lands #Tap_Lands
# 1x Mystic Remora #Card_Advantage #Draw
# 1x Mystic Retrieval #Flashback #Recursion
# 1x Mystical Tutor #Search_For_Instant #Search_For_Sorcery #Search_To_Top_Of_Library #Tutors #search_for_instant #search_for_sorcery #search_to_top_of_library #standalone #tutors
# 1x Narset Transcendent #Card_Advantage #Copy #Draw #Hate
# 1x Narset's Reversal #Counter #Redirect
# 1x Narset, Parter of Veils #Card_Advantage #Hate
# 1x Negate #Counter #stopgap
# 1x Niv-Mizzet, Parun #3_Devotion #3_devotion #Blue_Devotion #Burn #Card_Advantage #Devotion #Draw #Evasive #Pinger #Red_Devotion #blue_devotion #card_advantage #devotion #draw #evasive #pinger #red_devotion #standalone
# 1x Opt #Cantrip #Card_Advantage #Dig #Draw #Scry #card_advantage #dig #draw
# 1x Pact of Negation #Counter
# 1x Past in Flames #Flashback #Recursion #flashback #stopgap
# 1x Path to Exile #Creature_-_Exile #Creature_Removal #Removal #creature_-_exile #creature_removal
# 1x Phyrexian Altar #Mana_Rocks #Other_Mana_Rocks #Sacrifice_Outlet
# 1x Polluted Delta #Fetch_Land #Fetches #Lands #Tutors
# 1x Ponder #Cantrip #Card_Advantage #Dig #card_advantage #dig
# 1x Prairie Stream #Azorius
# 1x Preordain #Cantrip #Card_Advantage #Scry #card_advantage
# 1x Primal Amulet #Copy #Copy_Instant #Copy_Sorcery #Cost_Reduction
# 1x Prismatic Vista #Fetch_Basic #Tutors
# 1x Pull from Tomorrow #Card_Advantage #Discard #Draw
# 1x Purphoros, God of the Forge #Bomb #Burn #Devotion #Devotion_Matters #Direct_Damage #Indestructible #Mana_Sink #Spell_Slinger #bomb #devotion #devotion_matters #direct_damage #indestructible #mana_sink #spell_slinger #standalone #tokens_matter #wincon
# 1x Ral, Izzet Viceroy
# 1x Ral, Storm Conduit #Copy #Scry
# 1x Reflecting Pool
# 1x Reliquary Tower
# 1x Render Silent #Counter
# 1x Return to Dust #Artifact_-_Exile #Artifact_Removal #Enchantment_-_Exile #Enchantment_Removal #Removal
# 1x Reverberate #Copy #Copy_Instant #Copy_Sorcery #Redirect #amplify #copy #copy_instant #copy_sorcery
# 1x Rhystic Study #Card_Advantage #Draw
# 1x Rugged Prairie #Filter_Lands #Lands
# 1x Sacred Foundry #Lands #Shock_Lands
# 1x Saheeli Rai #Copy #Copy_Artifact #Copy_Creature #Direct_Damage #Reserved #Scry #Search_For_Artifact #Tutors
# 1x Saheeli, Sublime Artificer #+1/+1_Counter_Source #+1/+1_counter_source #Spell_Slinger #Token_Source #engine #spell_slinger #standalone #token_source
# 1x Scalding Tarn #Fetch_Land #Fetches #Izzet_Mana #Lands #Tutors
# 1x Sea of Clouds #Azorius
# 1x Search for Azcanta #Card_Advantage #Draw
# 1x Sensei's Divining Top #Card_Advantage #Draw
# 1x Serum Visions #Cantrip #Card_Advantage #Draw #Scry
# 1x Shared Animosity
# 1x Shivan Reef #Izzet_Mana #Lands #Pain_Lands
# 1x Skullclamp #Card_Advantage #Equipment #card_advantage #equipment
# 1x Sleight of Hand #Card_Advantage #Draw
# 1x Smothering Tithe #Ramp #Taxes #fixing #standalone #taxes
# 1x Snow-Covered Island
# 1x Snow-Covered Mountain
# 1x Snow-Covered Plains
# 1x Sol Ring #2_Colorless #Mana_Rocks #Ramp
# 1x Soulfire Grand Master #Bomb #Recurring_Card_Advantage #Recurring_Lifegain #Recursion #amplify #bomb #recurring_card_advantage #recurring_lifegain
# 1x Sphinx's Revelation #draw
# 1x Spirebluff Canal #Fast_Lands #Izzet_Mana #Lands
# 1x Spirit Bonds #Indestructible #Token_Source
# 1x Steam Vents #Izzet_Mana #Lands #Shock_Lands
# 1x Sulfur Falls #Check_Lands #Izzet_Mana #Lands
# 1x Sunbaked Canyon
# 1x Sunforger #Card_Advantage #Cost_Reduction #Draw #Equipment #Other_Cost_Reduction #Search_By_CMC #Search_For_Instant #Tutors
# 1x Supreme Verdict #Board_Wipes #Creature_Removal #Creatures_-_Mass_Destroy #Mass_Removal #Removal #Uncounterable
# 1x Swan Song #Counter #Noncreature_Permanent_-_Counter #Removal #noncreature_permanent_-_counter
# 1x Swiftfoot Boots #Equipment
# 1x Swiftwater Cliffs #Gain_Lands #Izzet_Mana #Lands #Lifegain
# 1x Swords to Plowshares #Bomb #Creature_-_Exile #Creature_Removal #Lifegain #Removal #bomb #creature_-_exile #creature_removal
# 1x Taigam, Ojutai Master #Spell_Slinger #spell_slinger #standalone
# 1x Talisman of Conviction #Boros #Mana_Rocks #Ramp #fixing #mana_rocks #tier2
# 1x Talisman of Creativity #Izzet #Mana_Rocks #Ramp #fixing #mana_rocks #tier2
# 1x Talisman of Progress #1_Colorless #1_colorless #Azorius #Mana_Rocks #Ramp #Talismans #fixing #mana_rocks #talismans #tier2
# 1x Talrand, Sky Summoner #Evasive #Spell_Slinger #Token_Source #engine #evasive #spell_slinger #token_source
# 1x Teferi's Protection #Board_Wipes #Other_Board_Wipes #Protection
# 1x Teferi, Hero of Dominaria #Card_Advantage #Draw #Nonland_Permanent_-_Bounce #Permanent_-_Exile #Ramp #Removal
# 1x Teferi, Time Raveler #Flash
# 1x Temple of Enlightenment #Azorius_Mana #Lands #Scry_Lands
# 1x Temple of Epiphany #Izzet #Lands #Scry #Scry_Lands #fixing #lands #scry_lands
# 1x Temple of Triumph #Lands #Scry_Lands
# 1x Terramorphic Expanse #Basic_Fetches #Fetch_Land #Lands #Tutors
# 1x The Locust God #Card_Advantage #Evasive #Token_Source #card_advantage #evasive #standalone #token_source
# 1x Thought Vessel #1_Colorless #Mana_Rocks #Ramp
# 1x Thousand-Year Storm #Copy #Copy_Instant #Copy_Sorcery #Copy_Spell #Storm
# 1x Time Spiral #Card_Advantage #Draw #Graveyard_Hate #Hate #Reserved
# 1x Time Wipe #Board_Wipes #Creatures_-_Mass_Destroy
# 1x Tranquil Cove #Azorius_Mana #Gain_Lands #Lands #Lifegain
# 1x Treasure Cruise #Card_Advantage #Delve #Draw
# 1x Trinket Mage #Cost_Reduction #Other_Cost_Reduction #Search_By_CMC #Search_For_Artifact #Tutors #cost_reduction #other_cost_reduction #search_by_cmc #search_for_artifact #tutors
# 1x Twilight Drover #Token_Source #amplify #token_source #tokens_matter
# 1x Vandalblast #Artifact_-_Destroy #Artifacts_-_Mass_Destroy #Board_Wipes #Removal
# 1x Wayfarer's Bauble #Fetch_Basic #Fetch_Land #Tutor_Basic_Land #Tutors
# 1x Wear #Artifact_Removal #Enchantment_Removal #Removal #artifact_removal #enchantment_removal
# 1x Wheel of Fortune #Card_Advantage #Draw #Reserved
# 1x Wind-Scarred Crag #Gain_Lands #Lands #Lifegain
# 1x Windfall #Card_Advantage #Draw #Mass_Loot
# 1x Winds of Abandon #Board_Wipes #Creature_-_Exile #Creatures_-_Mass_Exile #Removal
# 1x Windswept Heath #Fetches #Lands
# 1x Wooded Foothills #Fetches #Lands
# 1x Young Pyromancer #+1/+1_Counter_Source #+1/+1_counter_source #Spell_Slinger #Token_Source #spell_slinger #standalone #token_source

# %% [markdown]
# ## remapping tool
