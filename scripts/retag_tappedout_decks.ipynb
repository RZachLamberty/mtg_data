# %% [markdown]
# # retag tappedout decks
#
# in order to get all decks normalized and tagged from a central source of taggings, I have built the neo4j tag database. the issue: the updated, normalized source for the "canonical" tags is metamox, which uses its own set of tags. this means I have some aliasing to do before the "source" tags and tappedout are synced. this is that work!

# %% [markdown]
# ## imports

# %%
import sys, os

sys.path.insert(0, os.path.realpath('../'))

# %%
import logging
import pickle

import networkx as nx
import numpy as np
import pandas as pd

from IPython.display import display
from ipywidgets import Button, Checkbox, Dropdown, Output, Text
from neo4j import basic_auth, GraphDatabase

from mtg.credentials import F_NEO_CONF, load_neo_config
from mtg.extract.neo4j import get_neo_tags, get_card_official_tags
from mtg.extract.tappedout import (TAPPEDOUT_SPECIAL_TAGS,
                                   TAPPEDOUT_TAGS_TO_REPLACE,
                                   TappedoutDeck,
                                   build_categories_df,
                                   get_all_categories)
from mtg.load.neo import digraph_to_neo
from mtg.utils import init_logging

# %%
init_logging()

# %% [markdown]
# ## function defs

# %%
deck_id = '19-09-19-grixis-rogues'
d = TappedoutDeck(deck_id=deck_id, ignore_lands=False, with_tags=True)
# Out:
# 2019-09-21 22:36:55,953 DEBUG    [mtg.extract.tappedout.get_categories:271] loading categories for deck 19-09-19-grixis-rogues
# 2019-09-21 22:37:29,123 WARNING  [mtg.decks.__init__:103] card not in card universe: "Lim-Dul's Vault"
# 2019-09-21 22:37:29,124 WARNING  [mtg.decks.__init__:103] card not in card universe: "Open Into Wonder"

# %%
print(d.text_description)
# Out:
# 1x AEtherize
# 1x Abyssal Specter
# 1x Acquire
# 1x Adaptive Automaton
# 1x Akki Underminer
# 1x Aqueous Form
# 1x Arbiter of the Ideal
# 1x Arcane Denial
# 1x Ash Barrens
# 1x Ashling, the Extinguisher
# 1x Auntie's Snitch
# 1x Balefire Dragon
# 1x Bane Alley Broker
# 1x Banshee of the Dread Choir
# 1x Barren Moor
# 1x Bident of Thassa
# 1x Bitterblossom
# 1x Blasphemous Act
# 1x Blatant Thievery
# 1x Blazing Specter
# 1x Blighted Agent
# 1x Blind Zealot
# 1x Blizzard Specter
# 1x Blood Crypt
# 1x Bloodchief Ascension
# 1x Bloodforged Battle-Axe
# 1x Bloodstained Mire
# 1x Bojuka Bog
# 1x Bonesplitter
# 1x Brainstorm
# 1x Bribery
# 1x Broodbirth Viper
# 1x Cabal Coffers
# 1x Cabal Executioner
# 1x Call of the Nightwing
# 1x Call to the Kindred
# 1x Cavalcade of Calamity
# 1x Cavern of Souls
# 1x Cephalid Constable
# 1x Changeling Outcast
# 1x Choked Estuary
# 1x Chromatic Lantern
# 1x Cloak and Dagger
# 1x Clutch of the Undercity
# 1x Coastal Piracy
# 1x Coat of Arms
# 1x Collective Restraint
# 1x Command Tower
# 1x Commander's Sphere
# 1x Control Magic
# 1x Corrosive Mentor
# 1x Counterspell
# 1x Countersquall
# 1x Cover of Darkness
# 1x Creeping Tar Pit
# 1x Crosis, the Purger
# 1x Crumbling Necropolis
# 1x Cryptic Command
# 1x Curiosity
# 1x Curious Obsession
# 1x Curse of Opulence
# 1x Curse of Stalked Prey
# 1x Curse of Verbosity
# 1x Curse of the Swine
# 1x Cyclonic Rift
# 1x Daring Thief
# 1x Darkness
# 1x Darkslick Shores
# 1x Darksteel Ingot
# 1x Darkwater Catacombs
# 1x Deathcult Rogue
# 1x Decree of Pain
# 1x Deepchannel Mentor
# 1x Deepfathom Skulker
# 1x Demon of Wailing Agonies
# 1x Demonic Tutor
# 1x Destructive Urge
# 1x Diabolic Tutor
# 1x Dimir Aqueduct
# 1x Dimir Charm
# 1x Dimir Cluestone
# 1x Dimir Cutpurse
# 1x Dimir Guildgate
# 1x Dimir Infiltrator
# 1x Dimir Keyrune
# 1x Dimir Locket
# 1x Dimir Signet
# 1x Dire Undercurrents
# 1x Disallow
# 1x Disciple of Deceit
# 1x Dismal Backwater
# 1x Dissipate
# 1x Dissipation Field
# 1x Dissolve
# 1x Distant Melody
# 1x Doom Blade
# 1x Doomsday Specter
# 1x Door of Destinies
# 1x Dowsing Dagger
# 1x Drana, Liberator of Malakir
# 1x Dreadhorde Arcanist
# 1x Dreadship Reef
# 1x Drowned Catacomb
# 1x Earwig Squad
# 1x Elbrus, the Binding Blade
# 1x Elder Mastery
# 1x Eternal of Harsh Truths
# 1x Evacuation
# 1x Evil Twin
# 1x Evolving Wilds
# 1x Exotic Orchard
# 1x Expedition Map
# 1x Explorer's Scope
# 1x Expropriate
# 1x Fact or Fiction
# 1x Faerie Duelist
# 1x Faerie Macabre
# 1x Fallen Shinobi
# 1x Fellwar Stone
# 1x Fetid Pools
# 1x Fiend of the Shadows
# 1x Fortune Thief
# 1x Frogtosser Banneret
# 1x Gateway Sneak
# 1x Ghastlord of Fugue
# 1x Ghost Quarter
# 1x Gilded Lotus
# 1x Glen Elendra Liege
# 1x Glint-Sleeve Siphoner
# 1x Go for the Throat
# 1x Goblin Racketeer
# 1x Goblin Tunneler
# 1x Goblin Vandal
# 1x Gonti, Lord of Luxury
# 1x Grave Titan
# 1x Graveblade Marauder
# 1x Gravelgill Duo
# 1x Grenzo's Ruffians
# 1x Grenzo, Dungeon Warden
# 1x Grenzo, Havoc Raiser
# 1x Guildpact Informant
# 1x Guiltfeeder
# 1x Halimar Depths
# 1x Hands of Binding
# 1x Harbor Bandit
# 1x Havengul Vampire
# 1x Heat of Battle
# 1x Hellkite Tyrant
# 1x Hellrider
# 1x Helm of the Ghastlord
# 1x Herald's Horn
# 1x Hero's Downfall
# 1x Hidden Strings
# 1x Hollow Specter
# 1x Humble Defector
# 1x Hypnotic Specter
# 1x Ilharg, the Raze-Boar
# 1x Inferno Titan
# 1x Infiltrator il-Kor
# 1x Ink-Eyes, Servant of Oni
# 1x Inkfathom Infiltrator
# 1x Inkfathom Witch
# 1x Invisible Stalker
# 1x Izzet Signet
# 1x Jace, Cunning Castaway
# 1x Jeering Instigator
# 1x Jhessian Thief
# 1x Jwar Isle Refuge
# 1x Keeper of Keys
# 1x Kheru Mind-Eater
# 1x Kindred Discovery
# 1x Kindred Dominance
# 1x Knacksaw Clique
# 1x Knowledge Exploitation
# 1x Kusari-Gama
# 1x Larceny
# 1x Last Thoughts
# 1x Latchkey Faerie
# 1x Latulla's Orders
# 1x Lightning Greaves
# 1x Liliana's Reaver
# 1x Lim-Dul's Vault
# 1x Lonely Sandbar
# 1x Looter il-Kor
# 1x Lord of the Void
# 1x Loyal Subordinate
# 1x Lu Xun, Scholar General
# 1x Mana Leak
# 1x Marang River Prowler
# 1x Marchesa's Decree
# 1x Marchesa's Infiltrator
# 1x Marchesa's Smuggler
# 1x Marchesa, the Black Rose
# 1x Markov Blademaster
# 1x Marsh Flitter
# 1x Mask of Memory
# 1x Mask of Riddles
# 1x Master Thief
# 1x Master of Cruelties
# 1x Master of Predicaments
# 1x Memory Plunder
# 1x Mephidross Vampire
# 1x Merfolk Spy
# 1x Metallic Mimic
# 1x Midnight Recovery
# 1x Mind Stone
# 1x Mindcrank
# 1x Mindleech Mass
# 1x Mirko Vosk, Mind Drinker
# 1x Mirri the Cursed
# 1x Mistblade Shinobi
# 1x Moonblade Shinobi
# 1x Moonsilver Spear
# 1x Morphic Pool
# 1x Morsel Theft
# 1x Mu Yanling
# 1x Murder
# 1x Mutavault
# 1x Myriad Landscape
# 1x Mystical Tutor
# 1x Necromaster Dragon
# 1x Necropolis Regent
# 1x Needle Specter
# 1x Negate
# 1x Neko-Te
# 1x Neurok Commando
# 1x Neurok Stealthsuit
# 1x Nezumi Graverobber / Nighteyes the Desecrator
# 1x Nicol Bolas
# 1x Night Dealings
# 1x Night Market Lookout
# 1x Nightveil Specter
# 1x Nightveil Sprite
# 1x Ninja of the Deep Hours
# 1x Niv-Mizzet, Dracogenius
# 1x Niv-Mizzet, Parun
# 1x Niv-Mizzet, the Firemind
# 1x No Mercy
# 1x Noggin Whack
# 1x Notion Thief
# 1x Notorious Throng
# 1x Obelisk of Urd
# 1x Ogre Slumlord
# 1x Oona's Blackguard
# 1x Open Into Wonder
# 1x Ophidian Eye
# 1x Orzhov Enforcer
# 1x Orzhov Racketeers
# 1x Painful Quandary
# 1x Perplex
# 1x Pestermite
# 1x Phage the Untouchable
# 1x Phyrexian Arena
# 1x Polluted Delta
# 1x Ponder
# 1x Pongify
# 1x Praetor's Grasp
# 1x Preordain
# 1x Price of Fame
# 1x Prickly Boggart
# 1x Prismatic Vista
# 1x Propaganda
# 1x Prying Blade
# 1x Pulse Tracker
# 1x Pyreheart Wolf
# 1x Quag Vampires
# 1x Quest for Pure Flame
# 1x Quickling
# 1x Quietus Spike
# 1x Raid Bombardment
# 1x Raiders' Wake
# 1x Rakdos Guildgate
# 1x Rakdos Signet
# 1x Rankle, Master of Pranks
# 1x Rapid Hybridization
# 1x Ratcatcher
# 1x Raving Dead
# 1x Reality Shift
# 1x Reliquary Tower
# 1x Revel in Riches
# 1x Rhystic Study
# 1x Riptide Pilferer
# 1x Rite of the Raging Storm
# 1x River of Tears
# 1x Robber of the Rich
# 1x Rogue's Gloves
# 1x Rogue's Passage
# 1x Rootwater Thief
# 1x Sakashima the Impostor
# 1x Scion of Darkness
# 1x Scroll Thief
# 1x Scytheclaw
# 1x Sedraxis Specter
# 1x Shadowmage Infiltrator
# 1x Shimian Specter
# 1x Shizo, Death's Storehouse
# 1x Shockmaw Dragon
# 1x Sigil of Sleep
# 1x Silent Specter
# 1x Silent-Blade Oni
# 1x Silumgar's Command
# 1x Skeleton Key
# 1x Skullclamp
# 1x Skyship Plunderer
# 1x Skysovereign, Consul Flagship
# 1x Sleeper's Robe
# 1x Slith Strider
# 1x Slither Blade
# 1x Smuggler's Copter
# 1x Sol Ring
# 1x Sower of Discord
# 1x Specter's Shroud
# 1x Spireside Infiltrator
# 1x Starke of Rath
# 1x Stealer of Secrets
# 1x Steam Vents
# 1x Stinkdrinker Bandit
# 1x Stolen Identity
# 1x Stoneforge Masterwork
# 1x Sturmgeist
# 1x Submerged Boneyard
# 1x Sudden Spoiling
# 1x Sunken Hollow
# 1x Sunken Ruins
# 1x Surveilling Sprite
# 1x Swan Song
# 1x Swiftfoot Boots
# 1x Sword of Body and Mind
# 1x Sword of Feast and Famine
# 1x Sword of Fire and Ice
# 1x Sword of Kaldra
# 1x Sword of Light and Shadow
# 1x Sword of Sinew and Steel
# 1x Sword of Truth and Justice
# 1x Sword of War and Peace
# 1x Sword of the Animist
# 1x Sygg, River Cutthroat
# 1x Syndicate Enforcer
# 1x Tainted Isle
# 1x Talisman of Dominance
# 1x Talon of Pain
# 1x Tandem Lookout
# 1x Temple of Deceit
# 1x Temple of the False God
# 1x Terminate
# 1x Terramorphic Expanse
# 1x Tetsuko Umezawa, Fugitive
# 1x Thada Adel, Acquisitor
# 1x Thalakos Deceiver
# 1x Thassa's Emissary
# 1x Thassa, God of the Sea
# 1x Thief of Sanity
# 1x Thieves' Fortune
# 1x Thought Vessel
# 1x Thraximundar
# 1x Thrummingbird
# 1x Tin Street Dodger
# 1x Torment of Hailfire
# 1x Torment of Scarabs
# 1x Treasure Cruise
# 1x Treasure Nabber
# 1x Trepanation Blade
# 1x Triton Shorestalker
# 1x True-Name Nemesis
# 1x Ulamog, the Ceaseless Hunger
# 1x Umezawa's Jitte
# 1x Unclaimed Territory
# 1x Undercity Plague
# 1x Undermine
# 1x Unscythe, Killer of Kings
# 1x Urborg, Tomb of Yawgmoth
# 1x Vampire Cutthroat
# 1x Vampiric Tutor
# 1x Vanquisher's Banner
# 1x Vraska, Scheming Gorgon
# 1x Wake Thrasher
# 1x War Tax
# 1x Watery Grave
# 1x Weatherlight
# 1x Wei Night Raiders
# 1x Whip of Erebos
# 1x Whirler Rogue
# 1x Whispering Madness
# 1x Whispersilk Cloak
# 1x Windrider Patrol
# 1x Wrexial, the Risen Deep
# 1x Zulaport Cutthroat

# %% [markdown]
# goal: every card gets (and only gets) tags that satisfy one of the following
#
# + it is any of the "official" tags connected to it in neo (at any distance)
#     + e.g. `(c:Card)-[*]->(t:Tag)`
# + it is a tappedout tag that has no alias to real tags
#     + e.g. `#already_have_this` stays, but `#lifegain` doesn't
#         + `(to:TappedoutTag {name: "#lifegain"})-[:IS_ALIAS_OF]->(t:Tag {name: "Lifegain"})`
# + it is one of the special tags that is deck-specific
#     + e.g. `#amplify` stays for cards in decks where `(c:Card)-[:HAS_TAG]->(t:Tag {name: "{deck_id} - Amplify"})`
#
# if a given tag doesn't satisfy one of those criteria, it will be removed. *note: this basically means "remove all tags that have 'real' aliases"*

# %%
neo_conf = load_neo_config(F_NEO_CONF)

# %%
# hack to make sure that the get_card_official_tags function gets
# updated; remove when done
import mtg.extract.neo4j as N
import importlib
importlib.reload(N)

get_card_official_tags = N.get_card_official_tags

# %% [markdown]
# ### official tags

# %%
tags_official = pd.DataFrame(get_card_official_tags(neo_conf,
                                                    card_names=d.df.name.unique().tolist()),
                             columns=['name', 'tag'])
# Out:
# 2019-09-21 22:37:55,334 INFO     [bulk_rename_tappedout_tags.get_card_official_tags:77] loading all official tags for 387 cards

# %%
tags_official.head()
# Out:
#                    name                       tag
# 0               Acquire                     tutor
# 1               Acquire  tutor - opponent library
# 2  Arbiter of the Ideal            card advantage
# 3         Arcane Denial            card advantage
# 4         Arcane Denial                   counter

# %% [markdown]
# drop the deck-specific tags as they could have only gotten to this side from tappedout to begin with

# %%
is_special = (tags_official
              .tag
              .str.contains('|'.join(TAPPEDOUT_SPECIAL_TAGS), case=False))

tags_official = tags_official[~is_special]

# %% [markdown]
# ### deck specific tags
#
# this set of tags exists as a constant across tappedout decks and is available as

# %%
TAPPEDOUT_SPECIAL_TAGS
# Out:
# ['amplify', 'engine', 'standalone', 'stopgap', 'wincon']

# %% [markdown]
# ### aliased tags
#
# these are to be *removed*, not kept

# %%
_, _, aliases = get_neo_tags(neo_conf)
tags_aliases = pd.DataFrame(aliases, columns=['tappedout_tag', 'tag'])
# Out:
# 2019-09-21 22:38:40,181 INFO     [bulk_rename_tappedout_tags.get_neo_tags:46] loading all known tags from bolt://localhost:7687
# 2019-09-21 22:38:40,277 INFO     [bulk_rename_tappedout_tags.get_neo_tags:52] loading all known tapped out alias tags from bolt://localhost:7687
# 2019-09-21 22:38:40,310 INFO     [bulk_rename_tappedout_tags.get_neo_tags:58] loading all known tapped out alias connections from bolt://localhost:7687

# %%
tags_aliases.head()
# Out:
# Empty DataFrame
# Columns: [tappedout_tag, tag]
# Index: []

# %% [markdown]
# ### actually doing the mapping
#
# we'll create one function to do this and apply it across the records

# %%
def clean_tappedout_tag(t):
    t = t.replace('#', '').replace('_', ' ')
    # remap some of them
    t = TAPPEDOUT_TAGS_TO_REPLACE.get(t, t)
    return t

def fix_tag_list(rec):
    name = rec['name']
    tag_list = rec.tag_list
    try:
        tags = {clean_tappedout_tag(t) for t in tag_list}
    except TypeError:
        tags = set()
    
    validated_tags = set()

    # add the "white list" tags from the database
    validated_tags.update(tags_official
                          [tags_official.name == name]
                          .tag
                          .unique())

    # add any "deck specific" tags
    special_tags = tags.intersection(TAPPEDOUT_SPECIAL_TAGS)
    validated_tags.update(special_tags)
    tags.difference_update(special_tags)

    # drop anything aliased (alias on the other side should
    # have been added above)
    tags.difference_update(tags_aliases.tappedout_tag.values)

    # anything that remains is good to add back in
    validated_tags.update(tags)

    return ['#{}'.format(_.replace(' ', '_'))
            for _ in sorted(validated_tags)]

# %% [markdown]
# replace the existing tag column in the df with the fixed one

# %%
d.df.loc[:, 'tag_list_old'] = d.df.tag_list
d.df.tag_list = d.df.apply(fix_tag_list, axis=1)

# %%
print(d.text_description)
# Out:
# 1x AEtherize
# 1x Abyssal Specter
# 1x Acquire #tutor #tutor_-_opponent_library
# 1x Adaptive Automaton
# 1x Akki Underminer
# 1x Aqueous Form
# 1x Arbiter of the Ideal #card_advantage
# 1x Arcane Denial #card_advantage #counter
# 1x Ash Barrens #cycling #land #land_-_cycling #tutor #tutor_-_land
# 1x Ashling, the Extinguisher
# 1x Auntie's Snitch
# 1x Balefire Dragon #mass_damage_-_creature #wrath
# 1x Bane Alley Broker
# 1x Banshee of the Dread Choir #copy #copy_-_creature #copy_-_planeswalker #multiplayer
# 1x Barren Moor #land #land_-_cycling
# 1x Bident of Thassa #card_advantage #carddraw
# 1x Bitterblossom #token_source
# 1x Blasphemous Act #mass_damage_-_creature #mass_removal #wrath
# 1x Blatant Thievery #mass_theft #theft #theft_-_indefinite
# 1x Blazing Specter
# 1x Blighted Agent
# 1x Blind Zealot #destroy_-_creature #removal
# 1x Blizzard Specter
# 1x Blood Crypt #land #land_-_shock
# 1x Bloodchief Ascension #drain_and_gain
# 1x Bloodforged Battle-Axe #copy #equipment
# 1x Bloodstained Mire #land
# 1x Bojuka Bog #hate #hate_-_graveyard
# 1x Bonesplitter #equipment
# 1x Brainstorm #cantrip #card_advantage #carddraw
# 1x Bribery #tutor #tutor_-_opponent_library
# 1x Broodbirth Viper #copy #copy_-_creature #copy_-_planeswalker #multiplayer
# 1x Cabal Coffers
# 1x Cabal Executioner
# 1x Call of the Nightwing #copy
# 1x Call to the Kindred
# 1x Cavalcade of Calamity
# 1x Cavern of Souls #land #lands_-_any_color
# 1x Cephalid Constable
# 1x Changeling Outcast
# 1x Choked Estuary
# 1x Chromatic Lantern #mana_-_any_color #mana_rock #ramp
# 1x Cloak and Dagger #equipment
# 1x Clutch of the Undercity #bounce_-_permanents #removal #tutor #tutor_-_cmc
# 1x Coastal Piracy
# 1x Coat of Arms #anthem
# 1x Collective Restraint
# 1x Command Tower #land #lands_-_any_color #mana_-_any_color
# 1x Commander's Sphere #card_advantage #carddraw #mana_rock #ramp
# 1x Control Magic #theft #theft_-_indefinite
# 1x Corrosive Mentor
# 1x Counterspell #cantrip #counter #counter_-_hard #mass_removal #removal
# 1x Countersquall
# 1x Cover of Darkness
# 1x Creeping Tar Pit #land #land_-_man_land
# 1x Crosis, the Purger
# 1x Crumbling Necropolis #land #land_-_tap
# 1x Cryptic Command #bounce_-_creature #bounce_-_permanents #removal
# 1x Curiosity
# 1x Curious Obsession
# 1x Curse of Opulence
# 1x Curse of Stalked Prey
# 1x Curse of Verbosity
# 1x Curse of the Swine #mass_removal #removal
# 1x Cyclonic Rift #mass_bounce_-_permanents #removal #wrath
# 1x Daring Thief #theft
# 1x Darkness
# 1x Darkslick Shores #land #land_-_fast
# 1x Darksteel Ingot #indestructible #mana_rock
# 1x Darkwater Catacombs #land #land_-_slow_filter
# 1x Deathcult Rogue
# 1x Decree of Pain #carddraw #cycling #mass_destroy_-_creature #mass_reduced_toughness_-_creature #wrath
# 1x Deepchannel Mentor
# 1x Deepfathom Skulker
# 1x Demon of Wailing Agonies
# 1x Demonic Tutor #tutor #tutor_-_any_card
# 1x Destructive Urge
# 1x Diabolic Tutor #tutor #tutor_-_any_card
# 1x Dimir Aqueduct #land #land_-_bounce_land
# 1x Dimir Charm #destroy_-_creature #removal
# 1x Dimir Cluestone #mana_rock
# 1x Dimir Cutpurse
# 1x Dimir Guildgate #land #land_-_gate
# 1x Dimir Infiltrator #tutor #tutor_-_cmc
# 1x Dimir Keyrune #mana_rock #ramp #unblockable
# 1x Dimir Locket
# 1x Dimir Signet #mana_-_dimir #mana_rock #ramp
# 1x Dire Undercurrents #carddraw #discard #enter_the_battlefield #enter_the_battlefield_matters
# 1x Disallow #counter #hate #hate_-_activation
# 1x Disciple of Deceit #tutor #tutor_-_cmc
# 1x Dismal Backwater #land #land_-_lifegain #lifegain
# 1x Dissipate
# 1x Dissipation Field
# 1x Dissolve
# 1x Distant Melody #card_advantage #carddraw #tribal_-_faerie
# 1x Doom Blade #destroy_-_creature #removal
# 1x Doomsday Specter
# 1x Door of Destinies #anthem
# 1x Dowsing Dagger
# 1x Drana, Liberator of Malakir
# 1x Dreadhorde Arcanist
# 1x Dreadship Reef #land #land_-_battery
# 1x Drowned Catacomb #land #land_-_check_land
# 1x Earwig Squad #removal #tutor #tutor_-_opponent_library
# 1x Elbrus, the Binding Blade #equipment
# 1x Elder Mastery
# 1x Eternal of Harsh Truths
# 1x Evacuation #mass_bounce_-_creature #wrath
# 1x Evil Twin #copy #copy_-_creature #destroy_-_creature #removal
# 1x Evolving Wilds #land #land_-_fetch #tutor
# 1x Exotic Orchard #land #lands_-_any_color #mana_-_any_color
# 1x Expedition Map #tutor #tutor_-_land
# 1x Explorer's Scope #equipment
# 1x Expropriate #multiplayer #theft #theft_-_indefinite #turns
# 1x Fact or Fiction #card_advantage #carddraw #dig
# 1x Faerie Duelist
# 1x Faerie Macabre #evasion #hate #hate_-_graveyard
# 1x Fallen Shinobi
# 1x Fellwar Stone #mana_rock
# 1x Fetid Pools #land #land_-_cycling
# 1x Fiend of the Shadows
# 1x Fortune Thief
# 1x Frogtosser Banneret #cost_reduction #cost_reduction_-_goblins #cost_reduction_-_rogues #cost_reduction_-_spells #ramp
# 1x Gateway Sneak
# 1x Ghastlord of Fugue #devotion
# 1x Ghost Quarter #destroy_-_land #land #land_-_destroy #land_-_destruction #removal
# 1x Gilded Lotus #mana_rock
# 1x Glen Elendra Liege #devotion #lord #tribal_-_faerie
# 1x Glint-Sleeve Siphoner
# 1x Go for the Throat #destroy_-_creature #removal
# 1x Goblin Racketeer
# 1x Goblin Tunneler
# 1x Goblin Vandal #destroy_-_artifact #removal
# 1x Gonti, Lord of Luxury #removal #theft
# 1x Grave Titan
# 1x Graveblade Marauder
# 1x Gravelgill Duo
# 1x Grenzo's Ruffians
# 1x Grenzo, Dungeon Warden
# 1x Grenzo, Havoc Raiser #goad #removal
# 1x Guildpact Informant
# 1x Guiltfeeder
# 1x Halimar Depths
# 1x Hands of Binding
# 1x Harbor Bandit
# 1x Havengul Vampire
# 1x Heat of Battle
# 1x Hellkite Tyrant #mass_theft #theft #theft_-_indefinite
# 1x Hellrider
# 1x Helm of the Ghastlord
# 1x Herald's Horn #cost_reduction #cost_reduction_-_creatures #cost_reduction_-_spells
# 1x Hero's Downfall #destroy_-_creature #destroy_-_planeswalker #removal
# 1x Hidden Strings
# 1x Hollow Specter
# 1x Humble Defector #card_advantage #carddraw #theft #theft_-_indefinite
# 1x Hypnotic Specter
# 1x Ilharg, the Raze-Boar
# 1x Inferno Titan
# 1x Infiltrator il-Kor
# 1x Ink-Eyes, Servant of Oni #reanimate #reanimate_-_creature
# 1x Inkfathom Infiltrator
# 1x Inkfathom Witch
# 1x Invisible Stalker
# 1x Izzet Signet #mana_rock
# 1x Jace, Cunning Castaway
# 1x Jeering Instigator #theft #theft_-_eot
# 1x Jhessian Thief
# 1x Jwar Isle Refuge #land #land_-_lifegain
# 1x Keeper of Keys #multiplayer
# 1x Kheru Mind-Eater
# 1x Kindred Discovery #card_advantage #carddraw #tribal_-_faerie
# 1x Kindred Dominance #mass_destroy_-_creature #tribal_-_faerie #wrath
# 1x Knacksaw Clique
# 1x Knowledge Exploitation #tutor #tutor_-_opponent_library
# 1x Kusari-Gama #equipment
# 1x Larceny
# 1x Last Thoughts
# 1x Latchkey Faerie
# 1x Latulla's Orders #destroy_-_artifact #removal
# 1x Lightning Greaves #equipment #evasion
# 1x Liliana's Reaver
# 1x Lim-Dul's Vault
# 1x Lonely Sandbar #land #land_-_cycling
# 1x Looter il-Kor
# 1x Lord of the Void #devotion
# 1x Loyal Subordinate
# 1x Lu Xun, Scholar General
# 1x Mana Leak
# 1x Marang River Prowler
# 1x Marchesa's Decree #multiplayer #prison
# 1x Marchesa's Infiltrator
# 1x Marchesa's Smuggler
# 1x Marchesa, the Black Rose
# 1x Markov Blademaster
# 1x Marsh Flitter
# 1x Mask of Memory #equipment
# 1x Mask of Riddles #equipment
# 1x Master Thief #theft #theft_-_artifact #theft_-_indefinite
# 1x Master of Cruelties
# 1x Master of Predicaments
# 1x Memory Plunder
# 1x Mephidross Vampire
# 1x Merfolk Spy
# 1x Metallic Mimic
# 1x Midnight Recovery
# 1x Mind Stone #card_advantage #carddraw #mana_rock
# 1x Mindcrank
# 1x Mindleech Mass
# 1x Mirko Vosk, Mind Drinker
# 1x Mirri the Cursed
# 1x Mistblade Shinobi #bounce_-_creature #removal
# 1x Moonblade Shinobi
# 1x Moonsilver Spear #equipment
# 1x Morphic Pool
# 1x Morsel Theft
# 1x Mu Yanling #turns
# 1x Murder #destroy_-_creature #removal
# 1x Mutavault #land #land_-_man_land
# 1x Myriad Landscape #land_-_fetch #tutor
# 1x Mystical Tutor #tutor #tutor_-_instant #tutor_-_sorcery #tutor_-_to_top_of_library
# 1x Necromaster Dragon
# 1x Necropolis Regent #devotion
# 1x Needle Specter
# 1x Negate #counter
# 1x Neko-Te #equipment
# 1x Neurok Commando
# 1x Neurok Stealthsuit #equipment
# 1x Nezumi Graverobber / Nighteyes the Desecrator
# 1x Nicol Bolas
# 1x Night Dealings #tutor #tutor_-_cmc
# 1x Night Market Lookout
# 1x Nightveil Specter #devotion
# 1x Nightveil Sprite
# 1x Ninja of the Deep Hours
# 1x Niv-Mizzet, Dracogenius
# 1x Niv-Mizzet, Parun #card_advantage #carddraw #devotion #devotion_-_red #direct_damage #evasion #ping
# 1x Niv-Mizzet, the Firemind #removal
# 1x No Mercy
# 1x Noggin Whack
# 1x Notion Thief
# 1x Notorious Throng #go_wide #tribal_-_faerie #turns
# 1x Obelisk of Urd
# 1x Ogre Slumlord
# 1x Oona's Blackguard #discard #tribal_-_faerie
# 1x Open Into Wonder
# 1x Ophidian Eye
# 1x Orzhov Enforcer
# 1x Orzhov Racketeers
# 1x Painful Quandary #lifedrain #taxes
# 1x Perplex #tutor #tutor_-_cmc
# 1x Pestermite
# 1x Phage the Untouchable #devotion
# 1x Phyrexian Arena #ad_nauseam #carddraw
# 1x Polluted Delta #land #land_-_fetch #tutor
# 1x Ponder #cantrip #card_advantage #dig
# 1x Pongify #destroy_-_creature #removal
# 1x Praetor's Grasp #tutor #tutor_-_opponent_library
# 1x Preordain #cantrip #card_advantage #scry
# 1x Price of Fame #destroy_-_creature #removal
# 1x Prickly Boggart
# 1x Prismatic Vista
# 1x Propaganda #prison
# 1x Prying Blade #equipment #mana_rock
# 1x Pulse Tracker
# 1x Pyreheart Wolf
# 1x Quag Vampires
# 1x Quest for Pure Flame
# 1x Quickling
# 1x Quietus Spike #equipment
# 1x Raid Bombardment
# 1x Raiders' Wake
# 1x Rakdos Guildgate #land #land_-_gate
# 1x Rakdos Signet #mana_-_rakdos #mana_rock
# 1x Rankle, Master of Pranks
# 1x Rapid Hybridization #destroy_-_creature #removal
# 1x Ratcatcher
# 1x Raving Dead
# 1x Reality Shift #exile_-_creature #removal #removal_-_creature
# 1x Reliquary Tower
# 1x Revel in Riches
# 1x Rhystic Study
# 1x Riptide Pilferer
# 1x Rite of the Raging Storm #politics
# 1x River of Tears
# 1x Robber of the Rich
# 1x Rogue's Gloves #equipment
# 1x Rogue's Passage
# 1x Rootwater Thief
# 1x Sakashima the Impostor #copy #copy_-_creature
# 1x Scion of Darkness #devotion #reanimate #reanimate_-_creature
# 1x Scroll Thief #card_advantage
# 1x Scytheclaw #equipment
# 1x Sedraxis Specter
# 1x Shadowmage Infiltrator
# 1x Shimian Specter
# 1x Shizo, Death's Storehouse #land
# 1x Shockmaw Dragon #mass_damage #mass_damage_-_creature #wrath
# 1x Sigil of Sleep #bounce_-_creature #removal
# 1x Silent Specter
# 1x Silent-Blade Oni
# 1x Silumgar's Command #destroy_-_planeswalker #removal
# 1x Skeleton Key #equipment
# 1x Skullclamp #card_advantage #carddraw #equipment
# 1x Skyship Plunderer
# 1x Skysovereign, Consul Flagship
# 1x Sleeper's Robe
# 1x Slith Strider
# 1x Slither Blade
# 1x Smuggler's Copter
# 1x Sol Ring #mana_rock #ramp
# 1x Sower of Discord
# 1x Specter's Shroud #equipment
# 1x Spireside Infiltrator
# 1x Starke of Rath #destroy_-_artifact #destroy_-_creature #removal #theft
# 1x Stealer of Secrets
# 1x Steam Vents #land #land_-_shock #mana_-_izzet
# 1x Stinkdrinker Bandit
# 1x Stolen Identity #clone #copy #recursion
# 1x Stoneforge Masterwork #equipment
# 1x Sturmgeist
# 1x Submerged Boneyard #land #land_-_tap
# 1x Sudden Spoiling
# 1x Sunken Hollow
# 1x Sunken Ruins #land #land_-_filter
# 1x Surveilling Sprite
# 1x Swan Song #counter #counter_-_noncreature_permanent #removal
# 1x Swiftfoot Boots #equipment
# 1x Sword of Body and Mind #equipment
# 1x Sword of Feast and Famine #equipment
# 1x Sword of Fire and Ice #equipment
# 1x Sword of Kaldra #equipment
# 1x Sword of Light and Shadow #equipment #recursion
# 1x Sword of Sinew and Steel
# 1x Sword of Truth and Justice
# 1x Sword of War and Peace #equipment
# 1x Sword of the Animist #equipment #land_-_fetch #tutor
# 1x Sygg, River Cutthroat
# 1x Syndicate Enforcer #extort
# 1x Tainted Isle #land #land_-_modal
# 1x Talisman of Dominance #mana_rock
# 1x Talon of Pain
# 1x Tandem Lookout
# 1x Temple of Deceit #land #land_-_scry
# 1x Temple of the False God #land #land_-_modal #land_-_multiple_colorless
# 1x Terminate #destroy_-_creature #removal
# 1x Terramorphic Expanse #land #land_-_fetch #tutor
# 1x Tetsuko Umezawa, Fugitive
# 1x Thada Adel, Acquisitor #evasion #theft #theft_-_artifact #tutor #tutor_-_artifact
# 1x Thalakos Deceiver #theft #theft_-_indefinite
# 1x Thassa's Emissary #card_advantage
# 1x Thassa, God of the Sea #devotion #devotion_matters #indestructible #scry #unblockable
# 1x Thief of Sanity #hate #hate_-_graveyard
# 1x Thieves' Fortune
# 1x Thought Vessel #mana_rock #ramp
# 1x Thraximundar
# 1x Thrummingbird
# 1x Tin Street Dodger
# 1x Torment of Hailfire
# 1x Torment of Scarabs
# 1x Treasure Cruise #card_advantage #carddraw #delve
# 1x Treasure Nabber #theft #theft_-_indefinite
# 1x Trepanation Blade #equipment
# 1x Triton Shorestalker
# 1x True-Name Nemesis
# 1x Ulamog, the Ceaseless Hunger #indestructible
# 1x Umezawa's Jitte #equipment
# 1x Unclaimed Territory #land #lands_-_any_color
# 1x Undercity Plague
# 1x Undermine
# 1x Unscythe, Killer of Kings #equipment
# 1x Urborg, Tomb of Yawgmoth
# 1x Vampire Cutthroat
# 1x Vampiric Tutor #tutor #tutor_-_to_top_of_library
# 1x Vanquisher's Banner #carddraw #lord #tribal_-_faerie
# 1x Vraska, Scheming Gorgon #destroy_-_creature #removal
# 1x Wake Thrasher
# 1x War Tax
# 1x Watery Grave #land #land_-_shock
# 1x Weatherlight
# 1x Wei Night Raiders
# 1x Whip of Erebos #lifegain #mass_haste
# 1x Whirler Rogue
# 1x Whispering Madness
# 1x Whispersilk Cloak #equipment
# 1x Windrider Patrol
# 1x Wrexial, the Risen Deep #recursion
# 1x Zulaport Cutthroat

# %% [markdown]
# ## remapping tool
